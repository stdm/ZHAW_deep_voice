# %% [markdown]
# # ArcFace Loss with gluon

# %% [markdown]
# ## Imports

# %%
import os

c = False
while not c:
    d = os.getcwd().split('/')
    if d[-1] != 'ZHAW_deep_voice':
        os.chdir('..')
    else:
        c = True


import numpy as np
import mxnet as mx
import time
import math
import matplotlib.pyplot as plt

from mxnet.gluon import nn
from mxnet.gluon import rnn
from mxnet.metric import Accuracy, TopKAccuracy, CompositeEvalMetric, check_label_shapes

from networks.lstm_arc_face.data_generator import load_data, get_iter

from common.utils.paths import *

# %%
class CrossEntropy(mx.metric.EvalMetric):
    def __init__(self, eps=1e-12, name='cross-entropy', output_names=None, label_names=None):
        super(CrossEntropy, self).__init__(name, eps=eps,output_names=output_names, label_names=label_names)
        self.eps = eps

    def update(self, labels, preds):
        labels, preds = check_label_shapes(labels, preds, True)
        for label, pred in zip(labels, preds):
            pred = mx.nd.softmax(pred, axis=1)
            label = label.asnumpy()
            pred = pred.asnumpy()

            label = label.ravel()
            assert label.shape[0] == pred.shape[0]
            prob = pred[np.arange(label.shape[0]), np.int64(label)]
            self.sum_metric += (-np.log(prob + self.eps)).sum()
            self.num_inst += label.shape[0]

# %% [markdown]
# ## Optimizer

# %%
lr = 0.001
lr_factor = 0.1
lr_steps = [50, 80, 100, 150, 200, 300]
wd = 0.0001
momentum = 0.9


def get_trainer(net):
    global lr, wd, momentum
    kv = mx.kv.create('device')
    trainer = mx.gluon.Trainer(net.collect_params(), 'sgd',
                               optimizer_params={'learning_rate': lr,
                                                 'wd': wd,
                                                 'momentum': momentum,
                                                 'multi_precision': True},
                               kvstore=kv)
    
    trainer = mx.gluon.Trainer(net.collect_params(), mx.optimizer.AdaDelta(), kvstore=kv)
    return trainer

def update_learning_rate(trainer, epoch):
    global lr, lr_factor, lr_steps
    
    new_lr = lr * (lr_factor ** int(np.sum(np.array(lr_steps) < epoch)))
    trainer.set_learning_rate(new_lr)
    return trainer

# %% [markdown]
# ## Models

# %%
class NetworkBlock(mx.gluon.HybridBlock):
    def __init__(self, n_classes, **kwargs):
        super(NetworkBlock, self).__init__(**kwargs)

        self.lstm_hidden_1 = 256
        self.lstm_hidden_2 = 256
        self.dense_hidden_1 = n_classes * 10
        self.dense_hidden_2 = n_classes * 5
        self.drop_rate_1 = 0.5
        self.drop_rate_2 = 0.25

        self.output_size = self.dense_hidden_2

        with self.name_scope():
            self.body = nn.HybridSequential(prefix='')
            self.body.add(rnn.LSTM(self.lstm_hidden_1, bidirectional=True))
            self.body.add(nn.Dropout(self.drop_rate_1))
            self.body.add(rnn.LSTM(self.lstm_hidden_2, bidirectional=True))
            self.body.add(nn.Dense(self.dense_hidden_1))
            self.body.add(nn.Dropout(self.drop_rate_2))
            self.body.add(nn.Dense(self.dense_hidden_2))

    def hybrid_forward(self, F, x):
        x = self.body(x)
        return x

# %%
class ArcFaceBlock(mx.gluon.HybridBlock):
    def __init__(self, n_classes, **kwargs):
        super(ArcFaceBlock, self).__init__(**kwargs)
        #self.s = 64.0
        self.s = 1.0
        self.arcface_m = 0.3
        
        #self.cosface_m = 0.2
        self.cosface_m = 0.0
        
        self.easy_margin = True
        
        self.cos_m = math.cos(self.arcface_m)
        self.sin_m = math.sin(self.arcface_m)
        
        self.th = math.cos(math.pi - self.arcface_m)
        self.mm = math.sin(math.pi - self.arcface_m) * self.arcface_m
        
        self.n_classes = n_classes
        with self.name_scope():
            self.body = nn.HybridSequential(prefix='')
            network_block = NetworkBlock(self.n_classes)
            self.body.add(network_block)
            self.last_fc_weight = self.params.get('last_fc_weight', shape=(self.n_classes, network_block.output_size))

    def hybrid_forward(self, F, x, label, last_fc_weight):
        embeddings = self.body(x)

        n_embeddings = F.L2Normalization(embeddings, mode='instance')
        n_weights = F.L2Normalization(last_fc_weight, mode='instance')
        last_fc = F.FullyConnected(n_embeddings, n_weights,
                                   no_bias = True, flatten=True,
                                   num_hidden=self.n_classes,
                                   name='last_fc')
        
        cos_theta = last_fc / self.s
        sin_theta = F.sqrt(1 - cos_theta ** 2)
        phi = cos_theta * self.cos_m - sin_theta * self.sin_m
        phi = phi - self.cosface_m
        
        if self.easy_margin:
            phi = F.where(cos_theta > 0, phi, cos_theta)
        else:
            phi = F.where(cos_theta > self.th, phi, cos_theta - self.mm)
        # convert label to one-hot
        one_hot = F.one_hot(label, depth=self.n_classes)
        # where(out_i = {x_i if condition_i else y_i)
        output = one_hot * phi + (1.0 - one_hot) * cos_theta
        output = output * self.s
        return output, last_fc

# %%
class ArcFaceBlock(mx.gluon.HybridBlock):
    def __init__(self, n_classes, **kwargs):
        super(ArcFaceBlock, self).__init__(**kwargs)
        self.s = 64.0
        self.m1 = 1.0
        self.m2 = 0.3
        self.m3 = 0.2
        self.n_classes = n_classes
        with self.name_scope():
            self.body = nn.HybridSequential(prefix='')
            network_block = NetworkBlock(self.n_classes)
            self.body.add(network_block)
            self.last_fc_weight = self.params.get('last_fc_weight', shape=(self.n_classes, network_block.output_size))

    def hybrid_forward(self, F, x, label, last_fc_weight):
        embeddings = self.body(x)

        norm_embeddings = F.L2Normalization(embeddings, mode='instance')
        norm_weights = F.L2Normalization(last_fc_weight, mode='instance')
        last_fc = F.FullyConnected(norm_embeddings, norm_weights, no_bias = True,
                                       num_hidden=self.n_classes, name='last_fc')

        original_target_logit = F.pick(last_fc, label, axis=1)
        theta = F.arccos(original_target_logit / self.s)
        if self.m1!=1.0:
            theta = theta*self.m1
        if self.m2>0.0:
            theta = theta+self.m2
        marginal_target_logit = F.cos(theta)
        if self.m3>0.0:
            marginal_target_logit = marginal_target_logit - self.m3
        gt_one_hot = F.one_hot(label, depth = self.n_classes, on_value = 1.0, off_value = 0.0)
        diff = marginal_target_logit - original_target_logit
        diff = diff * self.s
        diff = F.expand_dims(diff, 1)
        body = F.broadcast_mul(gt_one_hot, diff)
        out = last_fc + body
        return out, last_fc

# %% [markdown]
# ## Testing

# %%
def test(net, ctx, val_data, metric, loss):
    metric.reset()
    l = []
    for batch in val_data:
        data = mx.gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
        label = mx.gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
        outputs = []
        cur_l = []
        for X, y in zip(data, label):
            z, ze = net(X, y)
            L = loss(z, y)
            cur_l.append(np.mean(L.asnumpy()))
        l.append(np.mean(np.array(cur_l)))
        outputs = [net(X, y)[-1] for X, y in zip(data, label)]
        metric.update(label, outputs)
    name, indices = metric.get()
    return name, indices, np.mean(np.array(l))

def epoch_callback(net, epoch, time, metric, ctx, val_iter, loss, verbose=True):
    name, indices = metric.get()
    t_acc = indices[0]
    text1 = ('[Epoch %d]\t'%epoch)+'training:'
    for i in range(len(name)):
        text1 += '\t%s=%.6f'%(name[i],indices[i])
    name, indices, L = test(net, ctx, val_iter, metric, loss)
    v_acc = indices[0]
    text2 = ('[Epoch %d]\t'%epoch)+'validation:'
    for i in range(len(name)):
        text2 += '\t%s=%.6f'%(name[i],indices[i])
    if verbose:
        print('[Epoch %d]\ttime used:\t%f'%(epoch, time))
        print(text1)
        print(text2)
        print()
    return t_acc, v_acc, L

# %% [markdown]
# ## Training

# %%
# %matplotlib notebook
def train(train_data_path, batch_size, batches_per_epoch, max_epochs):
    ctx = []
    cvd = os.environ['CUDA_VISIBLE_DEVICES'].strip()
    if len(cvd) > 0:
        for i in range(len(cvd.split(','))):
            ctx.append(mx.gpu(i))
    if len(ctx) == 0:
        ctx = [mx.cpu()]
    
    metric = CompositeEvalMetric([Accuracy(), TopKAccuracy(5), CrossEntropy()])
    train_iter, val_iter, num_speakers = load_data(train_data_path, batch_size, batches_per_epoch)

    net = ArcFaceBlock(num_speakers, batch_size)
    net.hybridize()
    net.initialize(mx.init.Xavier())
    net.collect_params().reset_ctx(ctx)

    trainer = get_trainer(net)
    
    loss = mx.gluon.loss.SoftmaxCrossEntropyLoss()
    
    t_accs = []
    v_accs = []
    
    fig = plt.figure()
    train_ax = fig.add_subplot(211)
    val_ax = fig.add_subplot(212)
    plt.ion()

    fig.show()
    fig.canvas.draw()
    
    xs = []
    epoch = 0
    total_time = 0
    best_val_acc = 0
    best_train_acc = 0
    t_losses = []
    v_losses = []
    with open('accs.csv', 'w+') as file:
        file.write('epoch, train_acc, val_acc\n')
    while epoch < max_epochs:
        train_iter.reset()
        val_iter.reset()
        metric.reset()
        #trainer = update_learning_rate(trainer, epoch)
        start = time.time()
        cur_l = []
        for i, batch in enumerate(train_iter):
            x = batch.data[0]
            y = batch.label[0]
            outputs = []
            outputs_eval = []
            Ls = []
            with mx.autograd.record():
                z, ze = net(x, y)
                L = loss(z, y)
                Ls.append(L)
                outputs.append(z)
                outputs_eval.append(ze)
                mx.autograd.backward(Ls)
                
                cur_l.append(np.mean(L.asnumpy()))
            
            trainer.step(batch.data[0].shape[0])
            
            metric.update([y], outputs_eval)
            
        t_losses.append(np.mean(np.array(cur_l)))
        epoch_time = time.time() - start
        total_time += epoch_time
        t_acc, v_acc, v_l = epoch_callback(net, epoch, epoch_time, metric, ctx, val_iter, loss, verbose=False)
        v_losses.append(v_l)
        if t_acc > best_train_acc:
            best_train_acc = t_acc
            net.save_parameters('best_train_acc')
        if v_acc > best_val_acc:
            best_val_acc = v_acc
            net.save_parameters('best_val_acc')
        xs.append(epoch)
        t_accs.append(t_acc)
        v_accs.append(v_acc)
        
        train_ax.clear()
        train_ax.plot(xs, t_accs, xs, v_accs)
        train_ax.set_ylim(0,1)
        val_ax.clear()
        val_ax.plot(xs, t_losses, xs, v_losses)
        fig.canvas.draw()
        
        with open('accs.csv', 'a') as file:
            file.write('%d,%f,%f\n'%(epoch, t_acc, v_acc))
        epoch = epoch + 1

    net.save_parameters('final_epoch')
    print('Average epoch time: {}'.format(float(total_time)/(epoch - 1)))

# %%
train_data_path = get_speaker_pickle('speakers_100_50w_50m_not_reynolds_cluster')
max_epochs = 100000
batch_size = 128
batches_per_epoch = 10

train(train_data_path, batch_size, batches_per_epoch, max_epochs)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Epoch 0]	time used:	2.541685
# [Epoch 0]	training:	accuracy=0.010156	top_k_accuracy_5=0.057031	cross-entropy=4.598994
# [Epoch 0]	validation:	accuracy=0.002344	top_k_accuracy_5=0.017969	cross-entropy=4.639346
#
# [Epoch 1]	time used:	2.194261
# [Epoch 1]	training:	accuracy=0.015625	top_k_accuracy_5=0.048438	cross-entropy=4.602064
# [Epoch 1]	validation:	accuracy=0.000000	top_k_accuracy_5=0.018750	cross-entropy=4.664425
#
# [Epoch 2]	time used:	2.220006
# [Epoch 2]	training:	accuracy=0.008594	top_k_accuracy_5=0.062500	cross-entropy=4.597813
# [Epoch 2]	validation:	accuracy=0.000000	top_k_accuracy_5=0.003906	cross-entropy=4.666434
#
# [Epoch 3]	time used:	2.218224
# [Epoch 3]	training:	accuracy=0.014844	top_k_accuracy_5=0.067969	cross-entropy=4.598051
# [Epoch 3]	validation:	accuracy=0.000000	top_k_accuracy_5=0.005469	cross-entropy=4.672670
#
# [Epoch 4]	time used:	2.222583
# [Epoch 4]	training:	accuracy=0.014063	top_k_accuracy_5=0.058594	cross-entropy=4.595095
# [Epoch 4]	validation:	accuracy=0.000000	top_k_accuracy_5=0.006250	cross-entropy=4.673588
#
# [Epoch 5]	time used:	2.263889
# [Epoch 5]	training:	accuracy=0.014063	top_k_accuracy_5=0.061719	cross-entropy=4.592160
# [Epoch 5]	validation:	accuracy=0.000000	top_k_accuracy_5=0.001563	cross-entropy=4.673653
#
# [Epoch 6]	time used:	2.223679
# [Epoch 6]	training:	accuracy=0.018750	top_k_accuracy_5=0.076563	cross-entropy=4.588302
# [Epoch 6]	validation:	accuracy=0.000000	top_k_accuracy_5=0.000000	cross-entropy=4.687912
#
# [Epoch 7]	time used:	2.207861
# [Epoch 7]	training:	accuracy=0.011719	top_k_accuracy_5=0.065625	cross-entropy=4.593020
# [Epoch 7]	validation:	accuracy=0.000000	top_k_accuracy_5=0.017188	cross-entropy=4.674839
#
# [Epoch 8]	time used:	2.235946
# [Epoch 8]	training:	accuracy=0.014063	top_k_accuracy_5=0.067969	cross-entropy=4.592487
# [Epoch 8]	validation:	accuracy=0.000000	top_k_accuracy_5=0.015625	cross-entropy=4.655427
#
# [Epoch 9]	time used:	2.210508
# [Epoch 9]	training:	accuracy=0.022656	top_k_accuracy_5=0.079687	cross-entropy=4.583025
# [Epoch 9]	validation:	accuracy=0.000000	top_k_accuracy_5=0.023438	cross-entropy=4.647829
#
# [Epoch 10]	time used:	2.178546
# [Epoch 10]	training:	accuracy=0.026562	top_k_accuracy_5=0.082031	cross-entropy=4.573017
# [Epoch 10]	validation:	accuracy=0.000000	top_k_accuracy_5=0.017188	cross-entropy=4.643151
#
# [Epoch 11]	time used:	2.177000
# [Epoch 11]	training:	accuracy=0.016406	top_k_accuracy_5=0.114844	cross-entropy=4.568862
# [Epoch 11]	validation:	accuracy=0.000000	top_k_accuracy_5=0.010937	cross-entropy=4.629261
#
# [Epoch 12]	time used:	2.198283
# [Epoch 12]	training:	accuracy=0.024219	top_k_accuracy_5=0.107813	cross-entropy=4.563107
# [Epoch 12]	validation:	accuracy=0.001563	top_k_accuracy_5=0.026562	cross-entropy=4.616780
#
# [Epoch 13]	time used:	2.230007
# [Epoch 13]	training:	accuracy=0.026562	top_k_accuracy_5=0.101562	cross-entropy=4.552205
# [Epoch 13]	validation:	accuracy=0.001563	top_k_accuracy_5=0.028906	cross-entropy=4.599272
#
# [Epoch 14]	time used:	2.191015
# [Epoch 14]	training:	accuracy=0.025781	top_k_accuracy_5=0.111719	cross-entropy=4.545641
# [Epoch 14]	validation:	accuracy=0.003125	top_k_accuracy_5=0.034375	cross-entropy=4.589327
#
# [Epoch 15]	time used:	2.167242
# [Epoch 15]	training:	accuracy=0.016406	top_k_accuracy_5=0.110156	cross-entropy=4.541310
# [Epoch 15]	validation:	accuracy=0.005469	top_k_accuracy_5=0.035156	cross-entropy=4.587392
#
# [Epoch 16]	time used:	2.200872
# [Epoch 16]	training:	accuracy=0.022656	top_k_accuracy_5=0.114062	cross-entropy=4.525722
# [Epoch 16]	validation:	accuracy=0.002344	top_k_accuracy_5=0.036719	cross-entropy=4.589416
#
# [Epoch 17]	time used:	2.247967
# [Epoch 17]	training:	accuracy=0.027344	top_k_accuracy_5=0.117969	cross-entropy=4.522702
# [Epoch 17]	validation:	accuracy=0.005469	top_k_accuracy_5=0.047656	cross-entropy=4.535761
#
# [Epoch 18]	time used:	2.222200
# [Epoch 18]	training:	accuracy=0.025000	top_k_accuracy_5=0.149219	cross-entropy=4.493826
# [Epoch 18]	validation:	accuracy=0.008594	top_k_accuracy_5=0.042969	cross-entropy=4.557603
#
# [Epoch 19]	time used:	2.191911
# [Epoch 19]	training:	accuracy=0.034375	top_k_accuracy_5=0.135937	cross-entropy=4.487617
# [Epoch 19]	validation:	accuracy=0.005469	top_k_accuracy_5=0.058594	cross-entropy=4.510343
#
# [Epoch 20]	time used:	2.184826
# [Epoch 20]	training:	accuracy=0.026562	top_k_accuracy_5=0.139063	cross-entropy=4.458065
# [Epoch 20]	validation:	accuracy=0.001563	top_k_accuracy_5=0.038281	cross-entropy=4.523066
#
# [Epoch 21]	time used:	2.181380
# [Epoch 21]	training:	accuracy=0.032813	top_k_accuracy_5=0.136719	cross-entropy=4.440238
# [Epoch 21]	validation:	accuracy=0.017188	top_k_accuracy_5=0.052344	cross-entropy=4.493577
#
# [Epoch 22]	time used:	2.210173
# [Epoch 22]	training:	accuracy=0.026562	top_k_accuracy_5=0.147656	cross-entropy=4.419002
# [Epoch 22]	validation:	accuracy=0.001563	top_k_accuracy_5=0.064062	cross-entropy=4.486682
#
# [Epoch 23]	time used:	2.198073
# [Epoch 23]	training:	accuracy=0.032031	top_k_accuracy_5=0.146875	cross-entropy=4.397127
# [Epoch 23]	validation:	accuracy=0.000781	top_k_accuracy_5=0.042969	cross-entropy=4.462230
#
# [Epoch 24]	time used:	2.193882
# [Epoch 24]	training:	accuracy=0.032031	top_k_accuracy_5=0.150000	cross-entropy=4.387561
# [Epoch 24]	validation:	accuracy=0.001563	top_k_accuracy_5=0.025781	cross-entropy=4.455865
#
# [Epoch 25]	time used:	2.183716
# [Epoch 25]	training:	accuracy=0.033594	top_k_accuracy_5=0.147656	cross-entropy=4.377989
# [Epoch 25]	validation:	accuracy=0.004687	top_k_accuracy_5=0.031250	cross-entropy=4.453925
#
# [Epoch 26]	time used:	2.155960
# [Epoch 26]	training:	accuracy=0.033594	top_k_accuracy_5=0.154688	cross-entropy=4.345454
# [Epoch 26]	validation:	accuracy=0.002344	top_k_accuracy_5=0.027344	cross-entropy=4.415047
#
# [Epoch 27]	time used:	2.206387
# [Epoch 27]	training:	accuracy=0.037500	top_k_accuracy_5=0.149219	cross-entropy=4.319641
# [Epoch 27]	validation:	accuracy=0.003906	top_k_accuracy_5=0.046875	cross-entropy=4.396374
#
# [Epoch 28]	time used:	2.172534
# [Epoch 28]	training:	accuracy=0.034375	top_k_accuracy_5=0.146875	cross-entropy=4.317259
# [Epoch 28]	validation:	accuracy=0.012500	top_k_accuracy_5=0.053906	cross-entropy=4.375704
#
# [Epoch 29]	time used:	2.192645
# [Epoch 29]	training:	accuracy=0.025781	top_k_accuracy_5=0.151562	cross-entropy=4.305393
# [Epoch 29]	validation:	accuracy=0.008594	top_k_accuracy_5=0.030469	cross-entropy=4.442842
#
# [Epoch 30]	time used:	2.193526
# [Epoch 30]	training:	accuracy=0.037500	top_k_accuracy_5=0.144531	cross-entropy=4.318139
# [Epoch 30]	validation:	accuracy=0.004687	top_k_accuracy_5=0.035937	cross-entropy=4.397083
#
# [Epoch 31]	time used:	2.188042
# [Epoch 31]	training:	accuracy=0.036719	top_k_accuracy_5=0.149219	cross-entropy=4.292154
# [Epoch 31]	validation:	accuracy=0.001563	top_k_accuracy_5=0.033594	cross-entropy=4.376510
#
# [Epoch 32]	time used:	2.197658
# [Epoch 32]	training:	accuracy=0.031250	top_k_accuracy_5=0.142187	cross-entropy=4.288808
# [Epoch 32]	validation:	accuracy=0.003906	top_k_accuracy_5=0.031250	cross-entropy=4.366749
#
# [Epoch 33]	time used:	2.225085
# [Epoch 33]	training:	accuracy=0.029687	top_k_accuracy_5=0.146094	cross-entropy=4.270259
# [Epoch 33]	validation:	accuracy=0.003906	top_k_accuracy_5=0.031250	cross-entropy=4.369991
#
# [Epoch 34]	time used:	2.220747
# [Epoch 34]	training:	accuracy=0.029687	top_k_accuracy_5=0.139844	cross-entropy=4.255133
# [Epoch 34]	validation:	accuracy=0.003125	top_k_accuracy_5=0.026562	cross-entropy=4.344229
#
# [Epoch 35]	time used:	2.226634
# [Epoch 35]	training:	accuracy=0.041406	top_k_accuracy_5=0.156250	cross-entropy=4.234064
# [Epoch 35]	validation:	accuracy=0.002344	top_k_accuracy_5=0.026562	cross-entropy=4.373169
#
# [Epoch 36]	time used:	2.168867
# [Epoch 36]	training:	accuracy=0.024219	top_k_accuracy_5=0.134375	cross-entropy=4.258516
# [Epoch 36]	validation:	accuracy=0.006250	top_k_accuracy_5=0.026562	cross-entropy=4.332942
#
# [Epoch 37]	time used:	2.239482
# [Epoch 37]	training:	accuracy=0.035156	top_k_accuracy_5=0.147656	cross-entropy=4.246535
# [Epoch 37]	validation:	accuracy=0.003125	top_k_accuracy_5=0.026562	cross-entropy=4.368926
#
# [Epoch 38]	time used:	2.202924
# [Epoch 38]	training:	accuracy=0.033594	top_k_accuracy_5=0.144531	cross-entropy=4.213569
# [Epoch 38]	validation:	accuracy=0.000781	top_k_accuracy_5=0.020313	cross-entropy=4.325588
#
# [Epoch 39]	time used:	2.191851
# [Epoch 39]	training:	accuracy=0.033594	top_k_accuracy_5=0.135156	cross-entropy=4.218420
# [Epoch 39]	validation:	accuracy=0.004687	top_k_accuracy_5=0.030469	cross-entropy=4.331729
# [Epoch 40]	time used:	2.149853
# [Epoch 40]	training:	accuracy=0.031250	top_k_accuracy_5=0.162500	cross-entropy=4.213074
# [Epoch 40]	validation:	accuracy=0.004687	top_k_accuracy_5=0.025781	cross-entropy=4.336751
#
# [Epoch 41]	time used:	2.184589
# [Epoch 41]	training:	accuracy=0.030469	top_k_accuracy_5=0.136719	cross-entropy=4.220645
# [Epoch 41]	validation:	accuracy=0.005469	top_k_accuracy_5=0.040625	cross-entropy=4.302029
#
# [Epoch 42]	time used:	2.138004
# [Epoch 42]	training:	accuracy=0.029687	top_k_accuracy_5=0.145313	cross-entropy=4.210709
# [Epoch 42]	validation:	accuracy=0.006250	top_k_accuracy_5=0.033594	cross-entropy=4.313749
#
# [Epoch 43]	time used:	2.179616
# [Epoch 43]	training:	accuracy=0.032813	top_k_accuracy_5=0.148438	cross-entropy=4.207040
# [Epoch 43]	validation:	accuracy=0.003906	top_k_accuracy_5=0.040625	cross-entropy=4.308371
#
# [Epoch 44]	time used:	2.183294
# [Epoch 44]	training:	accuracy=0.042969	top_k_accuracy_5=0.171094	cross-entropy=4.177216
# [Epoch 44]	validation:	accuracy=0.002344	top_k_accuracy_5=0.028125	cross-entropy=4.320740
#
# [Epoch 45]	time used:	2.228509
# [Epoch 45]	training:	accuracy=0.033594	top_k_accuracy_5=0.146094	cross-entropy=4.217283
# [Epoch 45]	validation:	accuracy=0.001563	top_k_accuracy_5=0.025781	cross-entropy=4.285888
#
# [Epoch 46]	time used:	2.285005
# [Epoch 46]	training:	accuracy=0.036719	top_k_accuracy_5=0.159375	cross-entropy=4.179390
# [Epoch 46]	validation:	accuracy=0.007812	top_k_accuracy_5=0.035156	cross-entropy=4.292684
#
# [Epoch 47]	time used:	2.190827
# [Epoch 47]	training:	accuracy=0.026562	top_k_accuracy_5=0.145313	cross-entropy=4.201174
# [Epoch 47]	validation:	accuracy=0.004687	top_k_accuracy_5=0.019531	cross-entropy=4.296974
#
# [Epoch 48]	time used:	2.214416
# [Epoch 48]	training:	accuracy=0.040625	top_k_accuracy_5=0.166406	cross-entropy=4.164020
# [Epoch 48]	validation:	accuracy=0.006250	top_k_accuracy_5=0.034375	cross-entropy=4.274579
#
# [Epoch 49]	time used:	2.166827
# [Epoch 49]	training:	accuracy=0.040625	top_k_accuracy_5=0.184375	cross-entropy=4.162318
# [Epoch 49]	validation:	accuracy=0.007812	top_k_accuracy_5=0.040625	cross-entropy=4.284324
#
# [Epoch 50]	time used:	2.177690
# [Epoch 50]	training:	accuracy=0.030469	top_k_accuracy_5=0.161719	cross-entropy=4.173659
# [Epoch 50]	validation:	accuracy=0.007031	top_k_accuracy_5=0.029687	cross-entropy=4.276250
#
# [Epoch 51]	time used:	2.179112
# [Epoch 51]	training:	accuracy=0.033594	top_k_accuracy_5=0.137500	cross-entropy=4.167969
# [Epoch 51]	validation:	accuracy=0.006250	top_k_accuracy_5=0.037500	cross-entropy=4.296346
#
# [Epoch 52]	time used:	2.224111
# [Epoch 52]	training:	accuracy=0.031250	top_k_accuracy_5=0.161719	cross-entropy=4.169244
# [Epoch 52]	validation:	accuracy=0.004687	top_k_accuracy_5=0.029687	cross-entropy=4.269350
#
# [Epoch 53]	time used:	2.290259
# [Epoch 53]	training:	accuracy=0.037500	top_k_accuracy_5=0.156250	cross-entropy=4.160250
# [Epoch 53]	validation:	accuracy=0.005469	top_k_accuracy_5=0.042188	cross-entropy=4.263452
#
# [Epoch 54]	time used:	2.200846
# [Epoch 54]	training:	accuracy=0.039062	top_k_accuracy_5=0.160156	cross-entropy=4.152707
# [Epoch 54]	validation:	accuracy=0.007812	top_k_accuracy_5=0.031250	cross-entropy=4.271056
#
# [Epoch 55]	time used:	2.202611
# [Epoch 55]	training:	accuracy=0.040625	top_k_accuracy_5=0.168750	cross-entropy=4.153168
# [Epoch 55]	validation:	accuracy=0.006250	top_k_accuracy_5=0.033594	cross-entropy=4.257818
#
# [Epoch 56]	time used:	2.205557
# [Epoch 56]	training:	accuracy=0.041406	top_k_accuracy_5=0.181250	cross-entropy=4.148716
# [Epoch 56]	validation:	accuracy=0.007812	top_k_accuracy_5=0.029687	cross-entropy=4.236796
#
# [Epoch 57]	time used:	2.222353
# [Epoch 57]	training:	accuracy=0.048438	top_k_accuracy_5=0.172656	cross-entropy=4.149230
# [Epoch 57]	validation:	accuracy=0.005469	top_k_accuracy_5=0.039844	cross-entropy=4.231002
#
# [Epoch 58]	time used:	2.187412
# [Epoch 58]	training:	accuracy=0.044531	top_k_accuracy_5=0.180469	cross-entropy=4.143338
# [Epoch 58]	validation:	accuracy=0.013281	top_k_accuracy_5=0.043750	cross-entropy=4.245938
#
# [Epoch 59]	time used:	2.166413
# [Epoch 59]	training:	accuracy=0.040625	top_k_accuracy_5=0.182031	cross-entropy=4.178668
# [Epoch 59]	validation:	accuracy=0.015625	top_k_accuracy_5=0.042188	cross-entropy=4.241923
#
# [Epoch 60]	time used:	2.198485
# [Epoch 60]	training:	accuracy=0.046094	top_k_accuracy_5=0.193750	cross-entropy=4.108238
# [Epoch 60]	validation:	accuracy=0.006250	top_k_accuracy_5=0.037500	cross-entropy=4.245820
#
# [Epoch 61]	time used:	2.206252
# [Epoch 61]	training:	accuracy=0.053906	top_k_accuracy_5=0.167969	cross-entropy=4.137866
# [Epoch 61]	validation:	accuracy=0.007031	top_k_accuracy_5=0.042969	cross-entropy=4.243873
#
# [Epoch 62]	time used:	2.169815
# [Epoch 62]	training:	accuracy=0.049219	top_k_accuracy_5=0.170313	cross-entropy=4.131173
# [Epoch 62]	validation:	accuracy=0.006250	top_k_accuracy_5=0.037500	cross-entropy=4.247933
#
# [Epoch 63]	time used:	2.165684
# [Epoch 63]	training:	accuracy=0.051562	top_k_accuracy_5=0.194531	cross-entropy=4.158512
# [Epoch 63]	validation:	accuracy=0.014063	top_k_accuracy_5=0.043750	cross-entropy=4.226284
#
# [Epoch 64]	time used:	2.212255
# [Epoch 64]	training:	accuracy=0.053906	top_k_accuracy_5=0.196875	cross-entropy=4.128833
# [Epoch 64]	validation:	accuracy=0.011719	top_k_accuracy_5=0.041406	cross-entropy=4.224291
#
# [Epoch 65]	time used:	2.251510
# [Epoch 65]	training:	accuracy=0.053125	top_k_accuracy_5=0.178125	cross-entropy=4.129220
# [Epoch 65]	validation:	accuracy=0.013281	top_k_accuracy_5=0.046094	cross-entropy=4.223943
#
# [Epoch 66]	time used:	2.215588
# [Epoch 66]	training:	accuracy=0.054688	top_k_accuracy_5=0.192969	cross-entropy=4.124620
# [Epoch 66]	validation:	accuracy=0.010937	top_k_accuracy_5=0.050781	cross-entropy=4.204851
#
# [Epoch 67]	time used:	2.204368
# [Epoch 67]	training:	accuracy=0.057813	top_k_accuracy_5=0.204687	cross-entropy=4.128243
# [Epoch 67]	validation:	accuracy=0.015625	top_k_accuracy_5=0.050000	cross-entropy=4.271976
#
# [Epoch 68]	time used:	2.271262
# [Epoch 68]	training:	accuracy=0.045312	top_k_accuracy_5=0.204687	cross-entropy=4.117895
# [Epoch 68]	validation:	accuracy=0.009375	top_k_accuracy_5=0.064062	cross-entropy=4.223291
#
# [Epoch 69]	time used:	2.172834
# [Epoch 69]	training:	accuracy=0.060156	top_k_accuracy_5=0.221094	cross-entropy=4.119192
# [Epoch 69]	validation:	accuracy=0.015625	top_k_accuracy_5=0.059375	cross-entropy=4.231406
#
# [Epoch 70]	time used:	2.176435
# [Epoch 70]	training:	accuracy=0.041406	top_k_accuracy_5=0.197656	cross-entropy=4.126638
# [Epoch 70]	validation:	accuracy=0.014844	top_k_accuracy_5=0.050000	cross-entropy=4.225622
#
# [Epoch 71]	time used:	2.171989
# [Epoch 71]	training:	accuracy=0.045312	top_k_accuracy_5=0.181250	cross-entropy=4.137964
# [Epoch 71]	validation:	accuracy=0.017188	top_k_accuracy_5=0.054688	cross-entropy=4.216594
#
# [Epoch 72]	time used:	2.185292
# [Epoch 72]	training:	accuracy=0.057813	top_k_accuracy_5=0.201563	cross-entropy=4.097641
# [Epoch 72]	validation:	accuracy=0.008594	top_k_accuracy_5=0.044531	cross-entropy=4.225900
#
# [Epoch 73]	time used:	2.221294
# [Epoch 73]	training:	accuracy=0.059375	top_k_accuracy_5=0.208594	cross-entropy=4.137943
# [Epoch 73]	validation:	accuracy=0.012500	top_k_accuracy_5=0.061719	cross-entropy=4.217420
#
# [Epoch 74]	time used:	2.184107
# [Epoch 74]	training:	accuracy=0.050781	top_k_accuracy_5=0.204687	cross-entropy=4.126429
# [Epoch 74]	validation:	accuracy=0.010937	top_k_accuracy_5=0.071875	cross-entropy=4.195106
#
# [Epoch 75]	time used:	2.198212
# [Epoch 75]	training:	accuracy=0.051562	top_k_accuracy_5=0.203125	cross-entropy=4.121171
# [Epoch 75]	validation:	accuracy=0.011719	top_k_accuracy_5=0.075781	cross-entropy=4.198757
#
# [Epoch 76]	time used:	2.212359
# [Epoch 76]	training:	accuracy=0.062500	top_k_accuracy_5=0.217188	cross-entropy=4.113985
# [Epoch 76]	validation:	accuracy=0.014844	top_k_accuracy_5=0.072656	cross-entropy=4.206843
#
# [Epoch 77]	time used:	2.220132
# [Epoch 77]	training:	accuracy=0.045312	top_k_accuracy_5=0.205469	cross-entropy=4.121597
# [Epoch 77]	validation:	accuracy=0.010937	top_k_accuracy_5=0.065625	cross-entropy=4.227120
#
# [Epoch 78]	time used:	2.196419
# [Epoch 78]	training:	accuracy=0.058594	top_k_accuracy_5=0.227344	cross-entropy=4.115652
# [Epoch 78]	validation:	accuracy=0.019531	top_k_accuracy_5=0.080469	cross-entropy=4.183860
#
# [Epoch 79]	time used:	2.189652
# [Epoch 79]	training:	accuracy=0.050000	top_k_accuracy_5=0.208594	cross-entropy=4.104481
# [Epoch 79]	validation:	accuracy=0.015625	top_k_accuracy_5=0.067187	cross-entropy=4.202928
# [Epoch 80]	time used:	2.181167
# [Epoch 80]	training:	accuracy=0.053125	top_k_accuracy_5=0.215625	cross-entropy=4.100083
# [Epoch 80]	validation:	accuracy=0.007812	top_k_accuracy_5=0.066406	cross-entropy=4.218917
#
# [Epoch 81]	time used:	2.182351
# [Epoch 81]	training:	accuracy=0.055469	top_k_accuracy_5=0.217969	cross-entropy=4.131329
# [Epoch 81]	validation:	accuracy=0.018750	top_k_accuracy_5=0.082812	cross-entropy=4.226169
#
# [Epoch 82]	time used:	2.192784
# [Epoch 82]	training:	accuracy=0.060156	top_k_accuracy_5=0.213281	cross-entropy=4.123848
# [Epoch 82]	validation:	accuracy=0.020313	top_k_accuracy_5=0.090625	cross-entropy=4.186949
#
# [Epoch 83]	time used:	2.173562
# [Epoch 83]	training:	accuracy=0.057813	top_k_accuracy_5=0.197656	cross-entropy=4.107836
# [Epoch 83]	validation:	accuracy=0.025000	top_k_accuracy_5=0.090625	cross-entropy=4.219733
#
# [Epoch 84]	time used:	2.189526
# [Epoch 84]	training:	accuracy=0.059375	top_k_accuracy_5=0.211719	cross-entropy=4.131322
# [Epoch 84]	validation:	accuracy=0.023438	top_k_accuracy_5=0.088281	cross-entropy=4.173569
#
# [Epoch 85]	time used:	2.202210
# [Epoch 85]	training:	accuracy=0.060156	top_k_accuracy_5=0.226562	cross-entropy=4.112790
# [Epoch 85]	validation:	accuracy=0.028125	top_k_accuracy_5=0.103125	cross-entropy=4.179076
#
# [Epoch 86]	time used:	2.162693
# [Epoch 86]	training:	accuracy=0.055469	top_k_accuracy_5=0.199219	cross-entropy=4.103707
# [Epoch 86]	validation:	accuracy=0.032031	top_k_accuracy_5=0.100781	cross-entropy=4.188631
#
# [Epoch 87]	time used:	2.245346
# [Epoch 87]	training:	accuracy=0.055469	top_k_accuracy_5=0.222656	cross-entropy=4.104386
# [Epoch 87]	validation:	accuracy=0.023438	top_k_accuracy_5=0.103906	cross-entropy=4.184320
#
# [Epoch 88]	time used:	2.216947
# [Epoch 88]	training:	accuracy=0.060156	top_k_accuracy_5=0.213281	cross-entropy=4.094094
# [Epoch 88]	validation:	accuracy=0.024219	top_k_accuracy_5=0.096875	cross-entropy=4.199194
#
# [Epoch 89]	time used:	2.316335
# [Epoch 89]	training:	accuracy=0.062500	top_k_accuracy_5=0.210938	cross-entropy=4.094857
# [Epoch 89]	validation:	accuracy=0.027344	top_k_accuracy_5=0.109375	cross-entropy=4.189699
#
# [Epoch 90]	time used:	2.201414
# [Epoch 90]	training:	accuracy=0.057813	top_k_accuracy_5=0.231250	cross-entropy=4.103100
# [Epoch 90]	validation:	accuracy=0.025781	top_k_accuracy_5=0.092188	cross-entropy=4.179815
#
# [Epoch 91]	time used:	2.184981
# [Epoch 91]	training:	accuracy=0.070312	top_k_accuracy_5=0.215625	cross-entropy=4.109653
# [Epoch 91]	validation:	accuracy=0.029687	top_k_accuracy_5=0.105469	cross-entropy=4.194395
#
# [Epoch 92]	time used:	2.173420
# [Epoch 92]	training:	accuracy=0.055469	top_k_accuracy_5=0.196875	cross-entropy=4.122238
# [Epoch 92]	validation:	accuracy=0.024219	top_k_accuracy_5=0.106250	cross-entropy=4.165619
#
# [Epoch 93]	time used:	2.165369
# [Epoch 93]	training:	accuracy=0.057031	top_k_accuracy_5=0.206250	cross-entropy=4.115003
# [Epoch 93]	validation:	accuracy=0.022656	top_k_accuracy_5=0.095312	cross-entropy=4.209982
#
# [Epoch 94]	time used:	2.247180
# [Epoch 94]	training:	accuracy=0.059375	top_k_accuracy_5=0.208594	cross-entropy=4.121152
# [Epoch 94]	validation:	accuracy=0.022656	top_k_accuracy_5=0.099219	cross-entropy=4.235802
#
# [Epoch 95]	time used:	2.198682
# [Epoch 95]	training:	accuracy=0.048438	top_k_accuracy_5=0.217188	cross-entropy=4.106742
# [Epoch 95]	validation:	accuracy=0.032813	top_k_accuracy_5=0.121094	cross-entropy=4.158368
#
# [Epoch 96]	time used:	2.246024
# [Epoch 96]	training:	accuracy=0.038281	top_k_accuracy_5=0.189844	cross-entropy=4.101279
# [Epoch 96]	validation:	accuracy=0.019531	top_k_accuracy_5=0.096875	cross-entropy=4.189536
#
# [Epoch 97]	time used:	2.173036
# [Epoch 97]	training:	accuracy=0.053125	top_k_accuracy_5=0.218750	cross-entropy=4.098881
# [Epoch 97]	validation:	accuracy=0.022656	top_k_accuracy_5=0.100781	cross-entropy=4.175253
#
# [Epoch 98]	time used:	2.199548
# [Epoch 98]	training:	accuracy=0.053906	top_k_accuracy_5=0.202344	cross-entropy=4.121670
# [Epoch 98]	validation:	accuracy=0.018750	top_k_accuracy_5=0.103906	cross-entropy=4.191934
#
# [Epoch 99]	time used:	2.279537
# [Epoch 99]	training:	accuracy=0.050781	top_k_accuracy_5=0.217188	cross-entropy=4.110595
# [Epoch 99]	validation:	accuracy=0.025000	top_k_accuracy_5=0.113281	cross-entropy=4.170862
#
# [Epoch 100]	time used:	2.234782
# [Epoch 100]	training:	accuracy=0.060937	top_k_accuracy_5=0.223438	cross-entropy=4.105460
# [Epoch 100]	validation:	accuracy=0.023438	top_k_accuracy_5=0.114844	cross-entropy=4.174626
#
# [Epoch 101]	time used:	2.231144
# [Epoch 101]	training:	accuracy=0.076563	top_k_accuracy_5=0.223438	cross-entropy=4.101220
# [Epoch 101]	validation:	accuracy=0.025781	top_k_accuracy_5=0.119531	cross-entropy=4.215654
#
# [Epoch 102]	time used:	2.200979
# [Epoch 102]	training:	accuracy=0.053906	top_k_accuracy_5=0.210938	cross-entropy=4.114427
# [Epoch 102]	validation:	accuracy=0.028906	top_k_accuracy_5=0.127344	cross-entropy=4.159480
#
# [Epoch 103]	time used:	2.208608
# [Epoch 103]	training:	accuracy=0.049219	top_k_accuracy_5=0.203906	cross-entropy=4.099218
# [Epoch 103]	validation:	accuracy=0.022656	top_k_accuracy_5=0.133594	cross-entropy=4.195206
#
# [Epoch 104]	time used:	2.187879
# [Epoch 104]	training:	accuracy=0.051562	top_k_accuracy_5=0.202344	cross-entropy=4.129176
# [Epoch 104]	validation:	accuracy=0.019531	top_k_accuracy_5=0.112500	cross-entropy=4.166347
#
# [Epoch 105]	time used:	2.177313
# [Epoch 105]	training:	accuracy=0.057031	top_k_accuracy_5=0.225000	cross-entropy=4.090571
# [Epoch 105]	validation:	accuracy=0.035156	top_k_accuracy_5=0.138281	cross-entropy=4.172292
#
# [Epoch 106]	time used:	2.216213
# [Epoch 106]	training:	accuracy=0.053906	top_k_accuracy_5=0.212500	cross-entropy=4.102546
# [Epoch 106]	validation:	accuracy=0.022656	top_k_accuracy_5=0.109375	cross-entropy=4.242276
#
# [Epoch 107]	time used:	2.181528
# [Epoch 107]	training:	accuracy=0.053906	top_k_accuracy_5=0.200000	cross-entropy=4.109266
# [Epoch 107]	validation:	accuracy=0.027344	top_k_accuracy_5=0.122656	cross-entropy=4.187683
#
# [Epoch 108]	time used:	2.173729
# [Epoch 108]	training:	accuracy=0.046875	top_k_accuracy_5=0.212500	cross-entropy=4.102981
# [Epoch 108]	validation:	accuracy=0.028125	top_k_accuracy_5=0.136719	cross-entropy=4.165055
#
# [Epoch 109]	time used:	2.201265
# [Epoch 109]	training:	accuracy=0.060937	top_k_accuracy_5=0.207031	cross-entropy=4.110019
# [Epoch 109]	validation:	accuracy=0.030469	top_k_accuracy_5=0.121875	cross-entropy=4.187341
#
# [Epoch 110]	time used:	2.203822
# [Epoch 110]	training:	accuracy=0.052344	top_k_accuracy_5=0.214844	cross-entropy=4.113902
# [Epoch 110]	validation:	accuracy=0.035156	top_k_accuracy_5=0.130469	cross-entropy=4.180237
#
# [Epoch 111]	time used:	2.210904
# [Epoch 111]	training:	accuracy=0.058594	top_k_accuracy_5=0.214062	cross-entropy=4.112396
# [Epoch 111]	validation:	accuracy=0.033594	top_k_accuracy_5=0.145313	cross-entropy=4.201137
#
# [Epoch 112]	time used:	2.218526
# [Epoch 112]	training:	accuracy=0.046094	top_k_accuracy_5=0.218750	cross-entropy=4.115897
# [Epoch 112]	validation:	accuracy=0.037500	top_k_accuracy_5=0.144531	cross-entropy=4.179448
#
# [Epoch 113]	time used:	2.236912
# [Epoch 113]	training:	accuracy=0.042188	top_k_accuracy_5=0.205469	cross-entropy=4.109869
# [Epoch 113]	validation:	accuracy=0.032031	top_k_accuracy_5=0.142969	cross-entropy=4.168944
#
# [Epoch 114]	time used:	2.209547
# [Epoch 114]	training:	accuracy=0.060156	top_k_accuracy_5=0.234375	cross-entropy=4.095425
# [Epoch 114]	validation:	accuracy=0.042188	top_k_accuracy_5=0.153906	cross-entropy=4.155908
#
# [Epoch 115]	time used:	2.212384
# [Epoch 115]	training:	accuracy=0.050781	top_k_accuracy_5=0.222656	cross-entropy=4.099677
# [Epoch 115]	validation:	accuracy=0.034375	top_k_accuracy_5=0.153125	cross-entropy=4.154796
#
# [Epoch 116]	time used:	2.322369
# [Epoch 116]	training:	accuracy=0.048438	top_k_accuracy_5=0.196094	cross-entropy=4.120675
# [Epoch 116]	validation:	accuracy=0.032031	top_k_accuracy_5=0.156250	cross-entropy=4.158531
#
# [Epoch 117]	time used:	2.206564
# [Epoch 117]	training:	accuracy=0.046094	top_k_accuracy_5=0.221094	cross-entropy=4.109656
# [Epoch 117]	validation:	accuracy=0.019531	top_k_accuracy_5=0.122656	cross-entropy=4.151700

# %%
val_data_name = 'speakers_40_clustering_vs_reynolds'
